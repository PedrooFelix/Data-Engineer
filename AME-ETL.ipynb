# %% [markdown]
# # Importing libraries

# %%
# !pip install  scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
import os
pd.set_option("display.max_rows", 130)
import sqlalchemy as db
import numpy as np
#from sklearn.preprocessing import OrdinalEncode

# %% [markdown]
# # Reading the files

# %%
os.listdir()
# Out:
# ['Screen Shot 2021-03-09 at 6.37.07 PM.png',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'Screen Shot 2021-03-09 at 4.29.12 PM.png',
#  'Screen Shot 2021-03-09 at 9.47.08 PM.png',
#  'Processo-Seletivo-Ame-Data-Engineer-Desafio.pdf',
#  'base_de_respostas_10k_amostra.csv',
#  'Screen Shot 2021-03-09 at 4.36.59 PM.png',
#  'Screen Shot 2021-03-09 at 7.57.56 PM.png',
#  'Screen Shot 2021-03-09 at 8.39.02 PM.png',
#  'Screen Shot 2021-03-09 at 4.59.58 PM.png',
#  '.ipynb_checkpoints',
#  'Screen Shot 2021-03-09 at 9.39.30 PM.png',
#  'Processo-Seletivo-Ame-Data-Engineer-Desafio.docx',
#  'base_de_conhecimento.csv']

# %%
csv_respostas = pd.read_csv('base_de_respostas_10k_amostra.csv')

# %%
csv_base =pd.read_csv('base_de_conhecimento.csv')

# %%
pd.set_option("display.max_columns", 101)

# %%
csv_respostas
# Out:
#       Respondent Hobby OpenSource         Country         Student  \
# 0         101346    No         No   United States              No
# 1          44791   Yes         No         Germany              No
# 2          32306   Yes        Yes   United States              No
# 3          37142   Yes         No   United States  Yes, full-time
# 4          21745   Yes        Yes           Nepal              No
# ...          ...   ...        ...             ...             ...
# 9995       58612   Yes        Yes           India  Yes, full-time
# 9996       59267   Yes        Yes  United Kingdom              No
# 9997       16127   Yes        Yes  United Kingdom              No
# 9998       38416   Yes        Yes     Netherlands              No
# 9999       18879   Yes         No         Germany  Yes, part-time
#
#                                              Employment  \
# 0                                    Employed full-time
# 1                                    Employed full-time
# ...

# %% [markdown]
# # Understanding the data types

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %% [markdown]
# ## ESBOÇO

# %%
# esboço

# starting with the main table: respondente
# respondente_id int not null,                      #respondente id, same of the table primary key.
# 	nome varchar(45),                               ## not identified
# 	contrib_open_source boolean,                    # index 2 = OpenSource, yes or no, there's no null
# 	programa_hobby boolean,                         # index 1 = code as hobb, yes or no,there's no null 
# 	salario float,                                  # index 52= Salary, 
                                                    #salary type
                                                    # ConvertedSalary
                                                    #Salary, should be only monthly
                                                    # salary type, there's 3 types, monthly, yearly, weekly
                                                    # there's 3166 nulls. we shou
                                                    # we should interpret these nulls and see if we have to treat the
# 	sistema_operacional_id int,                     # OperatingSystem = Windows, MacOS, Linux-based, BSD/UNIX

# 	pais_id int,                                    # Country, there's 29 nulls
# 	empresa_id int                                  ## not identified

## : any problem or not identified in the db and has no meaning to have the column

# %% [markdown]
# ### LOOKING FOR ANOTHER RESOURCES TO COMPLEMENT THIS ANALYSIS

# %%
'''
ive found another resources in stackoverflow and i saw that the quiz was not asking for the name

i'm downloaded the file of the main stackoverflow and even then i didnt find, and i chose to continue the construction of the db without the name
also from kaggle i didnt find 


resources:
https://insights.stackoverflow.com/survey/2018
https://insights.stackoverflow.com/survey
https://www.kaggle.com/stackoverflow/stack-overflow-2018-developer-survey?select=survey_results_schema.csv

'''

# %% [markdown]
# # Seeing the main table

# %% [markdown]
# <img src="Screen Shot 2021-03-09 at 4.36.59 PM.png" width="300" height="250">

# %%
print('Database Structure')

print('-'*50)
print('Respondente')
print('respondent_id INTEGER primary key NOT NULL')
print('-'*50)
print('\n name')
print('Not identified and theres no reason because even the test is questioning this.\n')
print('-'*50)
print('\n contrib_open_source')
print(f'Data type: {csv_respostas["OpenSource"].dtypes}\n')

print(f'Value counts: {csv_respostas.OpenSource.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.OpenSource.isnull().sum()}\n')
print(f'{csv_respostas.columns[2]} column will be a boolean\n')

print('-'*50)
print('\n programa_hobby')
print(f'Data type: {csv_respostas["Hobby"].dtypes}\n')

print(f'Value counts: {csv_respostas.Hobby.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.Hobby.isnull().sum()}\n')
print(f'{csv_respostas.columns[1]} column will be a boolean\n')

print('-'*50)
print('''

Salário vazio ou com valor “NA” deve ser convertido para zero (0.0).

Salário deve ser sempre calculado em reais e mensal. 

Para esse cálculo você usará a coluna ConvertedSalary, 

que contém o salário anual. Considere que 1 dólar equivale a R$3,81.

''')

print('\n Salary')
print(f'Data type: {csv_respostas["Salary"].dtypes}\n')

print(f'Value counts: {csv_respostas.Salary.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.Salary.isnull().sum()}\n')
print(f'{csv_respostas.columns[52]} we have to analyse further\n')

print('-'*50)

print('\n SalaryType')
print(f'Data type: {csv_respostas["SalaryType"].dtypes}\n')

print(f'Value counts: {csv_respostas.SalaryType.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.SalaryType.isnull().sum()}\n')
print(f'{csv_respostas.columns[53]} we have to analyse further\n')

print('-'*50)

print('\n ConvertedSalary')
print(f'Data type: {csv_respostas["ConvertedSalary"].dtypes}\n')

print(f'Value counts: {csv_respostas.ConvertedSalary.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.ConvertedSalary.isnull().sum()}\n')
print(f'{csv_respostas.columns[54]} we have to analyse further\n')

print('-'*50)

print('\n sistema_operacional_id')
print(f'Data type: {csv_respostas["OperatingSystem"].dtypes}\n')

print(f'Value counts: {csv_respostas.OperatingSystem.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.OperatingSystem.isnull().sum()}\n')
print(f'{csv_respostas.columns[74]} it will be int and them we have to transform each category into a column \n')

print('-'*50)

print('\n pais_id')
print(f'Data type: {csv_respostas["Country"].dtypes}\n')

print(f'Value counts: {csv_respostas.Country.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.Country.isnull().sum()}\n')
print(f'{csv_respostas.columns[3]} it will be int and them we have to transform each category into a colum\n')

print('-'*50)

print('\n empresa_id')

print(f'it will be a primary key for a foreignkey in the table of empresa, to join the companysize. \n')

print('-'*50)
# Out:
# Database Structure
# --------------------------------------------------
# Respondente
# respondent_id INTEGER primary key NOT NULL
# --------------------------------------------------
#
#  name
# Not identified and theres no reason because even the test is questioning this.
#
# --------------------------------------------------
#
#  contrib_open_source
# Data type: object
#
# Value counts: No     5650
# Yes    4350
# Name: OpenSource, dtype: int64
#
# Number of nulls:0
#
# OpenSource column will be a boolean
#
# --------------------------------------------------
#
#  programa_hobby
# Data type: object
#
# Value counts: Yes    8102
# No     1898
# Name: Hobby, dtype: int64
#
# Number of nulls:0
#
# Hobby column will be a boolean
#
# --------------------------------------------------
#
#
# Salário vazio ou com valor “NA” deve ser convertido para zero (0.0).
#
# Salário deve ser sempre calculado em reais e mensal.
#
# Para esse cálculo você usará a coluna ConvertedSalary,
#
# ...

# %% [markdown]
# # Another Columns and how i will put them into the postgresSQL

# %% [markdown]
# <img src="Screen Shot 2021-03-09 at 4.29.12 PM.png" width="450" height="300">

# %% [markdown]
# ## empresa

# %% [markdown]
# <img src="Screen Shot 2021-03-09 at 4.59.58 PM.png" width="350" height="300">

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
print('Database Structure')
print('-'*50)
print('empresa')
print('empresa_id primary key NOT NULL')
print('-'*50)
print(f'Data type: {csv_respostas["CompanySize"].dtypes}\n')

print(f'Value counts: {csv_respostas.CompanySize.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.CompanySize.isnull().sum()}\n')
print(f'{csv_respostas.columns[8]} will be a string')
print(f'the max length : {max(csv_respostas["CompanySize"].str.len())}')

#print(f'Value counts: {max(csv_respostas.CompanySize)}\n')

      #for c in csv_respostas.CompanySize:
      
#        print('Max length of column %s: %s\n' %  (c, csv_respostas[c].map(len).max()))
# Out:
# Database Structure
# --------------------------------------------------
# empresa
# empresa_id primary key
# --------------------------------------------------
# Data type: object
#
# Value counts: 20 to 99 employees          1916
# 100 to 499 employees        1549
# 10,000 or more employees    1065
# 1,000 to 4,999 employees     889
# 10 to 19 employees           812
# Fewer than 10 employees      801
# 500 to 999 employees         489
# 5,000 to 9,999 employees     331
# Name: CompanySize, dtype: int64
#
# Number of nulls:2148
#
# CompanySize will be a string
# the max length : 24.0

# %% [markdown]
# ## Pais

# %% [markdown]
# <img src="Screen Shot 2021-03-09 at 6.37.07 PM.png" width="450" height="300">

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
    
print('Database Structure')
print('-'*50)
print('pais')
print('pais_id primary key NOT NULL')
print('-'*50)

print(f'Data type: {csv_respostas["Country"].dtypes}\n')

print(f'Value counts: \n{csv_respostas.Country.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.Country.isnull().sum()}\n')
print(f'{csv_respostas.columns[3]} will be a string')
print(f'the max length : {max(csv_respostas["Country"].str.len())}')

#print(f'Value counts: {max(csv_respostas.CompanySize)}\n')

      #for c in csv_respostas.CompanySize:
      
#        print('Max length of column %s: %s\n' %  (c, csv_respostas[c].map(len).max()))
# Out:
# Database Structure
# --------------------------------------------------
# pais
# pais_id primary key NOT NULL
# --------------------------------------------------
# Data type: object
#
# Value counts:
# United States     2350
# India             1124
# United Kingdom     749
# Germany            655
# Canada             360
#                   ...
# Turkmenistan         1
# Togo                 1
# Bahrain              1
# Oman                 1
# Namibia              1
# Name: Country, Length: 137, dtype: int64
#
# Number of nulls:29
#
# Country will be a string
# the max length : 41.0

# %% [markdown]
# ## Sistema Operacional

# %% [markdown]
# <img src="Screen Shot 2021-03-09 at 7.57.56 PM.png" width="450" height="300">

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
print('Database Structure')
print('-'*50)
print('sistema_operacional')
print('sistema_operaciona_id primary key NOT NULL')
print('-'*50)

print(f'Data type: {csv_respostas["OperatingSystem"].dtypes}\n')

print(f'Value counts: {csv_respostas.OperatingSystem.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.OperatingSystem.isnull().sum()}\n')
print(f'{csv_respostas.columns[74]} will be a string')
print(f'the max length : {max(csv_respostas["OperatingSystem"].str.len())}')

#print(f'Value counts: {max(csv_respostas.CompanySize)}\n')

      #for c in csv_respostas.CompanySize:
      
#        print('Max length of column %s: %s\n' %  (c, csv_respostas[c].map(len).max()))
# Out:
# Database Structure
# --------------------------------------------------
# sistema_operacional
# sistema_operaciona_id primary key NOT NULL
# --------------------------------------------------
# Data type: object
#
# Value counts: Windows        4215
# MacOS          2496
# Linux-based    1892
# BSD/Unix         17
# Name: OperatingSystem, dtype: int64
#
# Number of nulls:1380
#
# OperatingSystem will be a string
# the max length : 11.0

# %% [markdown]
# ## linguagem de programação

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
print('Database Structure')
print('-'*50)
print('linguagem de progração')
print('linguagem_programacao_id primary key NOT NULL')
print('-'*50)

print(f'Data type: {csv_respostas["LanguageWorkedWith"].dtypes}\n')

print(f'Value counts: {csv_respostas.LanguageWorkedWith.value_counts()}\n')
print(f'Number of nulls:{csv_respostas.LanguageWorkedWith.isnull().sum()}\n')
print(f'{csv_respostas.columns[65]} will be a string')
print(f'the max length : {max(csv_respostas["LanguageWorkedWith"].str.len())}')

#print(f'Value counts: {max(csv_respostas.CompanySize)}\n')

      #for c in csv_respostas.CompanySize:
      
#        print('Max length of column %s: %s\n' %  (c, csv_respostas[c].map(len).max()))
# Out:
# Database Structure
# --------------------------------------------------
# linguagem de progração
# linguagem_programacao_id primary key NOT NULL
# --------------------------------------------------
# Data type: object
#
# Value counts: C#;JavaScript;SQL;HTML;CSS                                                  154
# JavaScript;PHP;SQL;HTML;CSS                                                 141
# Java                                                                        118
# JavaScript;HTML;CSS                                                          98
# C#;JavaScript;SQL;TypeScript;HTML;CSS                                        94
#                                                                            ...
# C#;Java;JavaScript;Objective-C;Ruby;SQL;Swift;TypeScript;VB.NET;HTML;CSS      1
# C#;Clojure;Groovy;Java;JavaScript;Rust;SQL;Kotlin;HTML;CSS                    1
# C;C#;JavaScript;Objective-C;PHP;Python;SQL;HTML;CSS;Bash/Shell                1
# ...

# %%
csv_respostas.LanguageWorkedWith.unique()[0].split(';')[0]
# Out:
# 'C#'

# %% [markdown]
# ## responde usa linguagem:

# %% [markdown]
# <img src="Screen Shot 2021-03-09 at 8.39.02 PM.png" width="450" height="300">

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
print('Database Structure')
print('-'*50)
print('\nresp_usa_linguagem')
print('respondente_id integer primary key NOT NULL\n')
print('-'*50)
print('\nlinguagem_programacao_id integer primary key NOT NULL\n')
print('-'*50)

'''

Cada linha da tabela linguagem_programacao deve conter uma única linguagem de programação.

'''

print(f'\ni did not find the answer for the "momento" ')
# Out:
# Database Structure
# --------------------------------------------------
#
# resp_usa_linguagem
# respondente_id integer primary key NOT NULL
#
# --------------------------------------------------
#
# linguagem_programacao_id integer primary key NOT NULL
#
# --------------------------------------------------
#
# i did not find the answer for the "momento"

# %% [markdown]
# ## respondente usa ferramenta

# %% [markdown]
# <img src="Screen Shot 2021-03-09 at 9.47.08 PM.png" width="450" height="300">

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
print('Database Structure')
print('-'*50)
print('\nresp_usa_ferramenta')
print('ferramenta_comunic_id integer primary key NOT NULL\n')
print('-'*50)
print('\nnome varchar()\n')
print(f'\nthe max length : {max(csv_respostas["CommunicationTools"].str.len())}\n')
print('\nSo we have to put the comunication tool into the table, but \n')

'''

Cada linha da tabela ferramenta_comunic deve conter apenas uma ferramenta de comunicação.

'''
print('-'*50)
# Out:
# Database Structure
# --------------------------------------------------
#
# resp_usa_ferramenta
# ferramenta_comunic_id integer primary key NOT NULL
#
# --------------------------------------------------
#
# nome varchar()
#
# the max length : 278.0
# --------------------------------------------------

# %%
<img src="Screen Shot 2021-03-09 at 9.39.30 PM.png" width="450" height="300">

# %%
csv_base
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# ...

# %%
print('Database Structure')
print('-'*50)
print('\nresp_usa_ferramenta')
print('ferramenta_comunic_id integer primary key NOT NULL\n')
print('-'*50)
print('\nrespondente_id integer primary key NOT NULL\n')
print('-'*50)
# Out:
# Database Structure
# --------------------------------------------------
#
# resp_usa_ferramenta
# ferramenta_comunic_id integer primary key NOT NULL
#
# --------------------------------------------------
#
# respondente_id integer primary key NOT NULL
#
# --------------------------------------------------

# %% [markdown]
# # Now i gonna treat the data

# %% [markdown]
# ## main table - respondente treating salary

# %%
csv_respostas[['Salary','SalaryType','ConvertedSalary']]
# Out:
#       Salary SalaryType ConvertedSalary
# 0      50000        NaN           50000
# 1      65000     Yearly           79552
# 2     125000        NaN          125000
# 3        0.0        NaN             0.0
# 4        0.0        NaN             0.0
# ...      ...        ...             ...
# 9995     0.0    Monthly             0.0
# 9996  100000     Yearly          138904
# 9997   36000     Yearly           50005
# 9998     0.0        NaN             0.0
# 9999   43500     Yearly           53239
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### filling nulls

# %%
csv_respostas[['Salary','ConvertedSalary']] = csv_respostas[['Salary','ConvertedSalary']].fillna("0.0")

# %% [markdown]
# ### converted salary

# %%
map( lambda x: x.replace('.',''), '' )

# %%
csv_respostas['ConvertedSalary'].map(lambda x: str(x.replace('.','')).map('${:,.2"}'.format))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-4fe065edd694> in <module>
# ----> 1 csv_respostas['ConvertedSalary'].map(lambda x: str(x.replace('.','')).map('${:,.2"}'.format))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3968         dtype: object
#    3969         """
# -> 3970         new_values = super()._map_values(arg, na_action=na_action)
#    3971         return self._constructor(new_values, index=self.index).__finalize__(
#    3972             self, method="map"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
# converting all salaries
#csv_respostas['Salary']= pd.to_numeric(csv_respostas['Salary'],errors='coerce')
#csv_respostas['ConvertedSalary']= pd.to_numeric(csv_respostas['ConvertedSalary'],errors='coerce')
#csv_respostas[['Salary','ConvertedSalary']].style.format(".2")
csv_respostas.to_string(formatters={'Salary':'R${:,.2}'.format})
#csv_respostas[['Salary','ConvertedSalary']]=csv_respostas[['Salary','ConvertedSalary']].applymap(lambda x: int(x.replace('.','').split(',')[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-3bce366377b1> in <module>
#       3 #csv_respostas['ConvertedSalary']= pd.to_numeric(csv_respostas['ConvertedSalary'],errors='coerce')
#       4 #csv_respostas[['Salary','ConvertedSalary']].style.format(".2")
# ----> 5 csv_respostas.to_string(formatters={'Salary':'R${:,.2}'.format})
#       6 #csv_respostas[['Salary','ConvertedSalary']]=csv_respostas[['Salary','ConvertedSalary']].applymap(lambda x: int(x.replace('.','').split(',')[0]))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     881                 line_width=line_width,
#     882             )
# ...

# %%
#mask minor 
mask=csv_respostas['ConvertedSalary'].astype('float')<csv_respostas['Salary'].astype('float')

# %%
csv_respostas[mask]['Salary'].unique()
# Out:
# array(['420000', '31000', '30000', '169696969696969', '900000', '75000',
#        '350000', '50000', '650000', '65000', '180000', '105000', '575000',
#        '150000', '32119', '70000', '200000', '3850', '730000', '80000',
#        '90000', '48750', '135000', '24800000', '81730', '1800000', '3000',
#        '4000', '100000', '360000', '663432', '120000', '20000', '47040',
#        '40000', '42000', '800000', '91000', '116000', '340000', '61500',
#        '210000', '114000', '1100', '560000', '700000', '104051', '35000',
#        '28750', '2500', '1900000', '1000000', '500000', '15000', '35500',
#        '60000', '950000', '140000', '660000', '25000', '23000', '45000',
#        '28000', '54000000', '1708000', '130000', '600000', '10000',
#        '8000000', '1500000', '6655000', '840000', '72500', '460000',
#        '2500000', '72000', '52000', '12000', '1500', '15100', '55000000',
#        '1138500', '5574200', '400000', '213354096', '780000', '6000000',
# ...

# %% [markdown]
# ### monthly to yearly

# %%
mask_diferente_de_zero=csv_respostas['Salary']!='00'

# %%
mask=csv_respostas['SalaryType']=='Monthly'

# %%
mask_minor=csv_respostas['Salary']<'99999'

# %%
csv_respostas[mask][['Salary','ConvertedSalary','SalaryType']]
# Out:
#       Salary ConvertedSalary SalaryType
# 5       1800     R$26,436.00    Monthly
# 6     420000     R$20,004.00    Monthly
# 9       6000     R$88,116.00    Monthly
# 11      3000     R$11,232.00    Monthly
# 16     31000      R$5,820.00    Monthly
# ...      ...             ...        ...
# 9981     0.0             0.0    Monthly
# 9984   48000    R$704,952.00    Monthly
# 9988    8000     R$96,000.00    Monthly
# 9994  132000  R$1,000,000.00    Monthly
# 9995     0.0             0.0    Monthly
#
# [3307 rows x 3 columns]

# %% [markdown]
# ### monthly to year

# %%
mask_diferente_de_zero=csv_respostas['Salary']!='0.0'

# %%
mask=csv_respostas['SalaryType']=='Monthly'

# %%
mask_minor=csv_respostas['Salary']<'99999'

# %%
csv_respostas[mask&mask_minor&mask_diferente_de_zero][['Salary','ConvertedSalary','SalaryType']]
# Out:
#       Salary ConvertedSalary SalaryType
# 5       1800           26436    Monthly
# 6     420000           20004    Monthly
# 9       6000           88116    Monthly
# 11      3000           11232    Monthly
# 16     31000            5820    Monthly
# ...      ...             ...        ...
# 9971   27000           40428    Monthly
# 9980     300            4404    Monthly
# 9984   48000          704952    Monthly
# 9988    8000           96000    Monthly
# 9994  132000           1e+06    Monthly
#
# [2946 rows x 3 columns]

# %%
csv_respostas[mask&mask_minor&mask_diferente_de_zero]['Salary']
# Out:
#       Salary
# 5       1800
# 6     420000
# 9       6000
# 11      3000
# 16     31000
# ...      ...
# 9971   27000
# 9980     300
# 9984   48000
# 9988    8000
# 9994  132000
#
# [2946 rows x 1 columns]

# %%
mask = csv_respostas['Salary'].str.contains(',')

# %%
csv_respostas[mask]['Salary']#.astype(float)
# Out:
# 126         981,51
# 170     21,000,000
# 432      39,750.00
# 569        5000,00
# 974      22,000.00
# 1062    104,000.00
# 1360       2225,60
# 1455       3103,06
# 2026     20,000.00
# 2146     85,000.00
# 3123    115,000.00
# 3472     89,100.00
# 4016    165,000.00
# 4265     87,500.00
# 4628    162,000.00
# 5008     1,128,750
# 5747    110,000.00
# 5754    206,000.00
# 5801     50,000.00
# 6052    190,000.00
# 6078     8,200,000
# 6359    57,096,000
# 6441        3000,0
# 7103       8000,00
# 7210     88,500.00
# 7924       4000,00
# 8431    120,000.00
# 8510     95,000.00
# 8597    22,000,000
# 8701     3,500,000
# 8723       5050,00
# 8864        500,00
# 9052     40,000.00
# 9102       50,000.
# 9235        450,00
# 9447     35,000.00
# 9755       2688,82
# 9763     1,000,000
# Name: Salary, dtype: object

# %%
mask_dot
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 9995     True
# 9996    False
# 9997    False
# 9998     True
# 9999    False
# Name: Salary, Length: 10000, dtype: bool

# %%
mask_dot= csv_respostas['Salary'].str.contains('\.')

# %%
csv_respostas[mask_dot]['Salary']=csv_respostas[mask_dot]['Salary'].replace(',','')

# %%
csv_respostas[mask_dot]['Salary'].replace(',','')
# Out:
# 0        50000
# 1        65000
# 2       125000
# 3          0.0
# 4          0.0
#          ...
# 9995       0.0
# 9996    100000
# 9997     36000
# 9998       0.0
# 9999     43500
# Name: Salary, Length: 10000, dtype: object

# %%
csv_respostas.loc[mask_dot,'Salary']=csv_respostas['Salary'].str.replace(',',)

# %%
mask_comma= csv_respostas['Salary'].str.contains(',')

# %%
csv_respostas.loc[mask_comma,'Salary']
# Out:
# Series([], Name: Salary, dtype: object)

# %%
def tratamento(x):
    if len(x.split(','))>2:
        return x.replace(',','')
    else:
        return x.replace(',','.')

# %%
csv_respostas.loc[mask_comma,'Salary']=csv_respostas.loc[mask_comma,'Salary'].apply(tratamento)

# %%
csv_respostas.loc[mask_comma,'Salary']

# %%
mask_yearly=csv_respostas['SalaryType']=='Yearly'

# %%
mask_null=csv_respostas['SalaryType']==None

# %%
csv_respostas['NewConvertedSalary']=csv_respostas['NewConvertedSalary'].astype(float)

# %%
csv_respostas.loc[mask_yearly,'NewConvertedSalary']=csv_respostas.loc[mask_yearly,'ConvertedSalary']

# %%
csv_respostas.loc[mask,'NewConvertedSalary']=csv_respostas.loc[mask,'Salary'].astype(float)*12

# %%
csv_respostas[['NewConvertedSalary','Salary','ConvertedSalary','SalaryType']]
# Out:
#       NewConvertedSalary  Salary ConvertedSalary SalaryType
# 0               600000.0   50000           50000        NaN
# 1                79552.0   65000           79552     Yearly
# 2              1500000.0  125000          125000        NaN
# 3                    0.0     0.0             0.0        NaN
# 4                    0.0     0.0             0.0        NaN
# ...                  ...     ...             ...        ...
# 9995                 0.0     0.0             0.0    Monthly
# 9996            138904.0  100000          138904     Yearly
# 9997             50005.0   36000           50005     Yearly
# 9998                 0.0     0.0             0.0        NaN
# 9999             53239.0   43500           53239     Yearly
#
# [10000 rows x 4 columns]

# %%
csv_respostas['NewConvertedSalary']=csv_respostas['Salary'].astype(float)/12*3.81

# %%
csv_respostas[['NewConvertedSalary']]
# Out:
#       NewConvertedSalary
# 0               15875.00
# 1               20637.50
# 2               39687.50
# 3                   0.00
# 4                   0.00
# ...                  ...
# 9995                0.00
# 9996            31750.00
# 9997            11430.00
# 9998                0.00
# 9999            13811.25
#
# [10000 rows x 1 columns]

# %%
csv_respostas['NewConvertedSalary']=csv_respostas['Salary'].astype(float)/12*3.81

# %%
csv_respostas
# Out:
#       Respondent Hobby OpenSource         Country         Student  \
# 0         101346    No         No   United States              No
# 1          44791   Yes         No         Germany              No
# 2          32306   Yes        Yes   United States              No
# 3          37142   Yes         No   United States  Yes, full-time
# 4          21745   Yes        Yes           Nepal              No
# ...          ...   ...        ...             ...             ...
# 9995       58612   Yes        Yes           India  Yes, full-time
# 9996       59267   Yes        Yes  United Kingdom              No
# 9997       16127   Yes        Yes  United Kingdom              No
# 9998       38416   Yes        Yes     Netherlands              No
# 9999       18879   Yes         No         Germany  Yes, part-time
#
#                                              Employment  \
# 0                                    Employed full-time
# 1                                    Employed full-time
# ...

# %% [markdown]
# ## transforming name that will be uploaded

# %%
respondente = 'respondente_'

# %%
csv_respostas['Respondent']=csv_respostas['Respondent'].apply(lambda x : respondente+str(x))

# %%
csv_respostas['Respondent']

# %% [markdown]
# ## language worked with

# %%
x=csv_respostas['LanguageWorkedWith'].astype(str).apply(lambda x: x.split(';'))
# Out:
#   File "<ipython-input-170-6d5d2998f542>", line 1
#     x=csv_respostas['LanguageWorkedWith'].astype(str).apply(lambda x: x.split(';'))[i[0] for i in x ]
#                                                                                          ^
# SyntaxError: invalid syntax

# %%
csv_respostas['LanguageNew']=[i[0] for i in x ]

# %%
for i in x:
    c = i[0]
    print(c)
# Out:
# C#
# C
# Assembly
# C++
# C
# Java
# C
# nan
# C#
# JavaScript
# C++
# C
# Java
# Java
# Java
# nan
# Java
# Java
# C
# C++
# C#
# SQL
# nan
# JavaScript
# CoffeeScript
# JavaScript
# JavaScript
# Java
# JavaScript
# C#
# C#
# Java
# Java
# Java
# Erlang
# Matlab
# C#
# Clojure
# C
# C#
# C
# C
# Java
# nan
# C#
# JavaScript
# Java
# C#
# CoffeeScript
# C#
# Java
# Java
# C#
# C#
# Swift
# C++
# Assembly
# C++
# C#
# Java
# Go
# C++
# Assembly
# nan
# C
# nan
# C++
# JavaScript
# JavaScript
# CoffeeScript
# C++
# Assembly
# nan
# C
# C#
# C#
# C#
# JavaScript
# R
# Python
# C
# Assembly
# JavaScript
# Go
# nan
# C
# C#
# Python
# nan
# C++
# JavaScript
# nan
# C++
# C#
# C
# nan
# Groovy
# C++
# Assembly
# nan
# C#
# nan
# Go
# Go
# Java
# C++
# JavaScript
# JavaScript
# C++
# C
# C
# Assembly
# nan
# C
# nan
# C#
# C#
# Go
# C++
# Assembly
# C#
# C#
# nan
# PHP
# JavaScript
# C
# CoffeeScript
# Go
# Assembly
# Clojure
# SQL
# C#
# JavaScript
# C++
# C
# C
# JavaScript
# Go
# C++
# ...

# %%
csv_respostas['LanguageNew']
# Out:
# 0             C#
# 1              C
# 2       Assembly
# 3            C++
# 4              C
#           ...
# 9995        Java
# 9996          C#
# 9997      Matlab
# 9998         nan
# 9999           C
# Name: LanguageNew, Length: 10000, dtype: object

# %% [markdown]
# ## ferramenta comunicação

# %%
x=csv_respostas['CommunicationTools'].astype(str).apply(lambda x: x.split(';'))

# %%
csv_respostas['CommunicationNew']=[i[0] for i in x ]

# %%
csv_respostas['CommunicationNew'].value_counts()
# Out:
# nan                                                                   2770
# Confluence                                                            2245
# Office / productivity suite (Microsoft Office, Google Suite, etc.)    1176
# Google Hangouts/Chat                                                   986
# Slack                                                                  896
# Jira                                                                   839
# Facebook                                                               486
# Other chat system (IRC, proprietary software, etc.)                    278
# Other wiki tool (Github, Google Sites, proprietary software, etc.)     115
# HipChat                                                                101
# Trello                                                                  84
# Stack Overflow Enterprise                                               24
# Name: CommunicationNew, dtype: int64

# %%
csv_respostas['CommunicationNew'].str.contains('Office').sum()
# Out:
# 1176

# %%
mask_office=csv_respostas['CommunicationNew'].str.contains('Office')

# %%
csv_respostas.loc[mask_office,'CommunicationNew']='Office'

# %%
mask_other=csv_respostas['CommunicationNew'].str.contains('Other')

# %%
csv_respostas.loc[mask_other,'CommunicationNew']='Other'

# %% [markdown]
# # csv util = limpo

# %%
csv_util.reset_index(drop=True, inplace=True)

# %%
index = range(1,10001)

# %%
csv_util['id']=index

# %%
columns=['Respondent','OpenSource','Hobby','NewConvertedSalary','OperatingSystem','Country','CompanySize','LanguageNew','CommunicationNew']

# %%
csv_util=csv_respostas[columns]
# Out:
#               Respondent Hobby OpenSource         Country         Student  \
# 0     respondente_101346    No         No   United States              No
# 1      respondente_44791   Yes         No         Germany              No
# 2      respondente_32306   Yes        Yes   United States              No
# 3      respondente_37142   Yes         No   United States  Yes, full-time
# 4      respondente_21745   Yes        Yes           Nepal              No
# ...                  ...   ...        ...             ...             ...
# 9995   respondente_58612   Yes        Yes           India  Yes, full-time
# 9996   respondente_59267   Yes        Yes  United Kingdom              No
# 9997   respondente_16127   Yes        Yes  United Kingdom              No
# 9998   respondente_38416   Yes        Yes     Netherlands              No
# 9999   respondente_18879   Yes         No         Germany  Yes, part-time
#
#                                              Employment  \
# ...

# %%
csv_util.head(1)
# Out:
#            Respondent OpenSource Hobby  NewConvertedSalary OperatingSystem  \
# 0  respondente_101346         No    No             15875.0         Windows
#
#          Country           CompanySize LanguageNew CommunicationNew  \
# 0  United States  100 to 499 employees          C#            Slack
#
#    NUM_Operating  NUM_LanguageNew  NUM_CompanySize  NUM_CommunicationNew  \
# 0              3                3                3                     7
#
#    NUM_Country  id
# 0          130   1

# %%
#corrigindo o bd

# %%
create table respondente(
	respondente_id INTEGER PRIMARY KEY NOT NULL,
	contrib_open_source boolean not null,
	programa_hobby boolean not null,
	salario float,
	sistema_operacional_id smallint,
	pais_id smallint,
	empresa_id smallint
)

create table empresa(
	empresa_id smallint Primary Key NOT null,
	tamanho varchar(24)
)

create table pais(
	pais_id smallint primary key not null,
not not not not not not	nome_pais varchar(41) not not not not not not 
)

create table sistema_operacional(
	sistema_operacional_id smallint primary key not null,
	nome_sistema_operacional varchar(24)
)


create table linguagem_programacao(
	linguagem_programacao_id smallint primary key not null,
	nome_linguagem_programacao varchar(20)
)

create table resp_usa_linguagem(
	respondente_id smallint  not null,
	linguagem_programacao_id smallint not null
	--momento
)

not
create table resp_usa_linguagem(
	respondente_id smallint  not null,
	linguagem_programacao_id smallint not null
	--momento
)
not

create table ferramenta_comunic(
	ferramenta_comunic_id smallint primary key not null,
	nome_ferramenta_comunic varchar(25)
	--momento
)

create table resp_usa_ferramenta(
	respondente_id smallint not null,
	ferramenta_comunic_id smallint not null
)

# %%
csv_util.rename(columns={'respondente_id': 'nome', 'OpenSource': 'contrib_open_source',
                        'Hobby':'programa_hobby','NewConvertedSalary':'salario','OperatingSystem':'nome_sistema_operacional','Country':'nome_pais','CompanySize':'tamanho','LanguageNew':'nome_linguagem_programacao','CommunicationNew':'nome_ferramenta_comunic'
                         ,'NUM_Operating':'sistema_operacional_id','NUM_LanguageNew':'linguagem_programacao_id','NUM_CompanySize':'empresa_id','NUM_CommunicationNew':'ferramenta_comunic_id','NUM_Country':'pais_id'
                        }, inplace=True)
# Out:
# /Users/usuario/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ## length of each row that i will upload into the db

# %%
idx = csv_respostas["CommunicationNew"].apply(len).idxmax()

# %%
len(csv_respostas.iloc[idx,-1])
# Out:
# 25

# %%
idx = csv_respostas["LanguageNew"].apply(len).idxmax()

# %%
len(csv_respostas.iloc[idx,-2])
# Out:
# 20

# %%
csv_respostas
# Out:
#               Respondent Hobby OpenSource         Country         Student  \
# 0     respondente_101346    No         No   United States              No
# 1      respondente_44791   Yes         No         Germany              No
# 2      respondente_32306   Yes        Yes   United States              No
# 3      respondente_37142   Yes         No   United States  Yes, full-time
# 4      respondente_21745   Yes        Yes           Nepal              No
# ...                  ...   ...        ...             ...             ...
# 9995   respondente_58612   Yes        Yes           India  Yes, full-time
# 9996   respondente_59267   Yes        Yes  United Kingdom              No
# 9997   respondente_16127   Yes        Yes  United Kingdom              No
# 9998   respondente_38416   Yes        Yes     Netherlands              No
# 9999   respondente_18879   Yes         No         Germany  Yes, part-time
#
#                                              Employment  \
# ...

# %% [markdown]
# # SPLITTING THE CSV TO UPLOAD

# %% [markdown]
# ## Splitting Operating System

# %%
csv_util
# Out:
#               Respondent OpenSource Hobby  NewConvertedSalary OperatingSystem  \
# 0     respondente_101346         No    No            15875.00         Windows
# 1      respondente_44791         No   Yes            20637.50         Windows
# 2      respondente_32306        Yes   Yes            39687.50         Windows
# 3      respondente_37142         No   Yes                0.00           MacOS
# 4      respondente_21745        Yes   Yes                0.00         Windows
# ...                  ...        ...   ...                 ...             ...
# 9995   respondente_58612        Yes   Yes                0.00         Windows
# 9996   respondente_59267        Yes   Yes            31750.00         Windows
# 9997   respondente_16127        Yes   Yes            11430.00     Linux-based
# 9998   respondente_38416        Yes   Yes                0.00             NaN
# 9999   respondente_18879         No   Yes            13811.25         Windows
#
# ...

# %%
csv_util.OperatingSystem.unique()
# Out:
# array(['Windows', 'MacOS', 'Linux-based', nan, 'BSD/Unix'], dtype=object)

# %%
labelencoder = LabelEncoder()

# %%
csv_util['NUM_Operating'] = labelencoder.fit_transform(csv_util['OperatingSystem'].astype(str))
# Out:
# <ipython-input-280-8bdd0142b0a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_util['NUM_Operating'] = labelencoder.fit_transform(csv_util['OperatingSystem'].astype(str))

# %%
csv_util['NUM_Operating']
# Out:
# 0       3
# 1       3
# 2       3
# 3       2
# 4       3
#        ..
# 9995    3
# 9996    3
# 9997    1
# 9998    4
# 9999    3
# Name: NUM_Operating, Length: 10000, dtype: int64

# %%
#csv_util['NUM_Operating']=csv_util['OperatingSystem'].astype('category')
# Out:
# <ipython-input-273-91ccb28e288c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_util['OperatingSystem']=csv_util['OperatingSystem'].astype('category')

# %%
#csv_util['NUM_Operating'] = csv_util['OperatingSystem'].cat.codes
# Out:
# <ipython-input-274-177a5b10fd95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_util['NUM_Operating'] = csv_util['OperatingSystem'].cat.codes

# %%
csv_util.NUM_Operating.value_counts()
# Out:
# 3    4215
# 2    2496
# 1    1892
# 4    1380
# 0      17
# Name: NUM_Operating, dtype: int64

# %% [markdown]
# ## Splitting language

# %%
csv_util
# Out:
#               Respondent OpenSource Hobby  NewConvertedSalary OperatingSystem  \
# 0     respondente_101346         No    No            15875.00         Windows
# 1      respondente_44791         No   Yes            20637.50         Windows
# 2      respondente_32306        Yes   Yes            39687.50         Windows
# 3      respondente_37142         No   Yes                0.00           MacOS
# 4      respondente_21745        Yes   Yes                0.00         Windows
# ...                  ...        ...   ...                 ...             ...
# 9995   respondente_58612        Yes   Yes                0.00         Windows
# 9996   respondente_59267        Yes   Yes            31750.00         Windows
# 9997   respondente_16127        Yes   Yes            11430.00     Linux-based
# 9998   respondente_38416        Yes   Yes                0.00             NaN
# 9999   respondente_18879         No   Yes            13811.25         Windows
#
# ...

# %%
csv_util.LanguageNew.unique()
# Out:
# array(['C#', 'C', 'Assembly', 'C++', 'Java', 'nan', 'JavaScript', 'SQL',
#        'CoffeeScript', 'Erlang', 'Matlab', 'Clojure', 'Swift', 'Go', 'R',
#        'Python', 'Groovy', 'PHP', 'Haskell', 'VB.NET', 'Objective-C',
#        'HTML', 'Julia', 'Perl', 'Visual Basic 6', 'Scala', 'VBA', 'Ruby',
#        'Hack', 'Delphi/Object Pascal', 'TypeScript', 'Bash/Shell', 'F#',
#        'Lua', 'Rust', 'Kotlin', 'Cobol'], dtype=object)

# %%
csv_util['NUM_LanguageNew'] = labelencoder.fit_transform(csv_util['LanguageNew'].astype(str))
# Out:
# <ipython-input-285-b0d45f8f784a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_util['NUM_LanguageNew'] = labelencoder.fit_transform(csv_util['LanguageNew'].astype(str))

# %%
csv_util['NUM_LanguageNew']
# Out:
# 0        3
# 1        2
# 2        0
# 3        4
# 4        2
#         ..
# 9995    16
# 9996     3
# 9997    21
# 9998    36
# 9999     2
# Name: NUM_LanguageNew, Length: 10000, dtype: int64

# %% [markdown]
# ## Splitting businesssize

# %%
csv_util
# Out:
#               Respondent OpenSource Hobby  NewConvertedSalary OperatingSystem  \
# 0     respondente_101346         No    No            15875.00         Windows
# 1      respondente_44791         No   Yes            20637.50         Windows
# 2      respondente_32306        Yes   Yes            39687.50         Windows
# 3      respondente_37142         No   Yes                0.00           MacOS
# 4      respondente_21745        Yes   Yes                0.00         Windows
# ...                  ...        ...   ...                 ...             ...
# 9995   respondente_58612        Yes   Yes                0.00         Windows
# 9996   respondente_59267        Yes   Yes            31750.00         Windows
# 9997   respondente_16127        Yes   Yes            11430.00     Linux-based
# 9998   respondente_38416        Yes   Yes                0.00             NaN
# 9999   respondente_18879         No   Yes            13811.25         Windows
#
# ...

# %%
csv_util.CompanySize.unique()

# %%
csv_util['NUM_CompanySize'] = labelencoder.fit_transform(csv_util['CompanySize'].astype(str))
# Out:
# <ipython-input-292-8d4a98858928>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_util['NUM_CompanySize'] = labelencoder.fit_transform(csv_util['CompanySize'].astype(str))

# %%
csv_util['NUM_CompanySize']
# Out:
# 0       3
# 1       0
# 2       2
# 3       1
# 4       4
#        ..
# 9995    0
# 9996    8
# 9997    1
# 9998    8
# 9999    0
# Name: NUM_CompanySize, Length: 10000, dtype: int64

# %% [markdown]
# ## Splitting communicationtools

# %%
csv_util
# Out:
#               Respondent OpenSource Hobby  NewConvertedSalary OperatingSystem  \
# 0     respondente_101346         No    No            15875.00         Windows
# 1      respondente_44791         No   Yes            20637.50         Windows
# 2      respondente_32306        Yes   Yes            39687.50         Windows
# 3      respondente_37142         No   Yes                0.00           MacOS
# 4      respondente_21745        Yes   Yes                0.00         Windows
# ...                  ...        ...   ...                 ...             ...
# 9995   respondente_58612        Yes   Yes                0.00         Windows
# 9996   respondente_59267        Yes   Yes            31750.00         Windows
# 9997   respondente_16127        Yes   Yes            11430.00     Linux-based
# 9998   respondente_38416        Yes   Yes                0.00             NaN
# 9999   respondente_18879         No   Yes            13811.25         Windows
#
# ...

# %%
csv_util.CommunicationNew.unique()
# Out:
# array(['Slack', 'Jira', 'Office', 'Confluence', 'Facebook', 'nan',
#        'HipChat', 'Google Hangouts/Chat', 'Other', 'Trello',
#        'Stack Overflow Enterprise'], dtype=object)

# %%
csv_util['NUM_CommunicationNew'] = labelencoder.fit_transform(csv_util['CommunicationNew'].astype(str))
# Out:
# <ipython-input-296-7a7310cbe14f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_util['NUM_CommunicationNew'] = labelencoder.fit_transform(csv_util['CommunicationNew'].astype(str))

# %%
csv_util['NUM_CommunicationNew']
# Out:
# 0        7
# 1        4
# 2        5
# 3        7
# 4        7
#         ..
# 9995     1
# 9996     0
# 9997     0
# 9998    10
# 9999     0
# Name: NUM_CommunicationNew, Length: 10000, dtype: int64

# %% [markdown]
# ## Splitting Country

# %%
csv_util.Country.unique()
# Out:
# array(['United States', 'Germany', 'Nepal', 'Portugal', 'Hungary',
#        'Pakistan', 'Egypt', 'Brazil', 'Belgium', 'Andorra', 'Viet Nam',
#        'India', 'Italy', 'United Kingdom', 'Nigeria',
#        'Russian Federation', 'Romania', 'Kenya',
#        'Iran, Islamic Republic of...', 'France', 'Netherlands', 'China',
#        'Australia', 'Canada', 'Bangladesh', 'Taiwan', 'Israel', 'Spain',
#        'Venezuela, Bolivarian Republic of...', 'Mexico', 'Lebanon',
#        'Malaysia', 'Sweden', 'Poland', 'Norway', 'Greece', 'Ireland',
#        'Bulgaria', 'Slovenia', 'Indonesia', 'Latvia', 'Belarus',
#        'El Salvador', 'Costa Rica', 'Switzerland', 'Denmark',
#        'Czech Republic', 'Austria', 'Japan', 'Turkey', 'South Korea',
#        'Madagascar', 'Philippines', 'United Arab Emirates', 'Bolivia',
#        'South Africa', 'Ukraine', 'Estonia', 'Colombia', nan, 'Peru',
#        'New Zealand', 'Argentina', 'Hong Kong (S.A.R.)', 'Singapore',
# ...

# %%
csv_util['NUM_Country'] = labelencoder.fit_transform(csv_util['Country'].astype(str))
# Out:
# <ipython-input-299-eb06908ae720>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_util['NUM_Country'] = labelencoder.fit_transform(csv_util['Country'].astype(str))

# %%
csv_util['NUM_Country']
# Out:
# 0       130
# 1        42
# 2       130
# 3       130
# 4        81
#        ...
# 9995     50
# 9996    128
# 9997    128
# 9998     82
# 9999     42
# Name: NUM_Country, Length: 10000, dtype: int64

# %% [markdown]
# # Making the structure of the database using dataframes

# %% [markdown]
# <img src="Screen Shot 2021-03-11 at 4.15.55 PM.png" width="720" height="720">

# %%
csv_util.head(1)
# Out:
#                  nome contrib_open_source programa_hobby  salario  \
# 0  respondente_101346                  No             No  15875.0
#
#   nome_sistema_operacional      nome_pais               tamanho  \
# 0                  Windows  United States  100 to 499 employees
#
#   nome_linguagem_programacao nome_ferramenta_comunic  sistema_operacional_id  \
# 0                         C#                   Slack                       3
#
#    linguagem_programacao_id  empresa_id  ferramenta_comunic_id  pais_id  id
# 0                         3           3                      7      130   1

# %%
respondente=csv_util[['id','nome','contrib_open_source','programa_hobby','salario','sistema_operacional_id','pais_id','empresa_id']]

# %%
empresa
# Out:
#    empresa_id                   tamanho
# 0           3      100 to 499 employees
# 1           0  1,000 to 4,999 employees
# 2           2  10,000 or more employees
# 3           1        10 to 19 employees
# 4           4        20 to 99 employees
# 5           8                       NaN
# 6           6      500 to 999 employees
# 7           7   Fewer than 10 employees
# 8           5  5,000 to 9,999 employees

# %%
csv_util['empresa_id'].unique()
# Out:
# array([3, 0, 2, 1, 4, 8, 6, 7, 5])

# %%
csv_util.append()
# Out:
# Object `.append()` not found.

# %%
pd.DataFrame(csv_util.groupby(['empresa_id','tamanho']).sum().index.to_list(),columns=['empresa_id','tamanho']).append({'empresa_id':8, 'tamanho':None},ignore_index=True)
# Out:
#    empresa_id                   tamanho
# 0         0.0  1,000 to 4,999 employees
# 1         1.0        10 to 19 employees
# 2         2.0  10,000 or more employees
# 3         3.0      100 to 499 employees
# 4         4.0        20 to 99 employees
# 5         5.0  5,000 to 9,999 employees
# 6         6.0      500 to 999 employees
# 7         7.0   Fewer than 10 employees
# 8         8.0                       NaN

# %%
empresa=pd.DataFrame({"empresa_id":csv_util['empresa_id'].unique(), "tamanho": csv_util['tamanho'].unique()})

# %%
pais=pd.DataFrame({"pais_id":csv_util['pais_id'].unique(), "nome_pais": csv_util['nome_pais'].unique()})

# %%
sistema_operacional=pd.DataFrame({"sistema_operacional_id":csv_util['sistema_operacional_id'].unique(), "nome_sistema_operacional": csv_util['nome_sistema_operacional'].unique()})

# %%
linguagem_programacao=pd.DataFrame({"linguagem_programacao_id":csv_util['linguagem_programacao_id'].unique(), "nome_linguagem_programacao": csv_util['nome_linguagem_programacao'].unique()})

# %%
resp_usa_linguagem=pd.DataFrame({"id":csv_util['id'].unique(), "linguagem_programacao_id": csv_util['linguagem_programacao_id']})

# %%
resp_usa_ferramenta=pd.DataFrame({"id":csv_util['id'].unique(), "ferramenta_comunic_id": csv_util['ferramenta_comunic_id']})

# %%
ferramenta_comunic=pd.DataFrame({"ferramenta_comunic_id":csv_util['ferramenta_comunic_id'].unique(), "nome_ferramenta_comunic": csv_util['nome_ferramenta_comunic'].unique()})

# %% [markdown]
# # uploading to postgresSQL

# %%
csv_util
# Out:
#               Respondent OpenSource Hobby  NewConvertedSalary OperatingSystem  \
# 0     respondente_101346         No    No            15875.00         Windows
# 1      respondente_44791         No   Yes            20637.50         Windows
# 2      respondente_32306        Yes   Yes            39687.50         Windows
# 3      respondente_37142         No   Yes                0.00           MacOS
# 4      respondente_21745        Yes   Yes                0.00         Windows
# ...                  ...        ...   ...                 ...             ...
# 9995   respondente_58612        Yes   Yes                0.00         Windows
# 9996   respondente_59267        Yes   Yes            31750.00         Windows
# 9997   respondente_16127        Yes   Yes            11430.00     Linux-based
# 9998   respondente_38416        Yes   Yes                0.00             NaN
# 9999   respondente_18879         No   Yes            13811.25         Windows
#
# ...

# %%
#THERES 2 WAYS TO DO THIS

# %%
engine = db.create_engine('postgresql://postgres:admin@localhost/AME_BD')

# %%
conn = engine.connect()

# %%
db_server = 'postgresql'
user = 'postgres'
password = 'admin'
ip = 'localhost'
db_name = 'AME_BD'

# create the engine
engine = db.create_engine(f'{db_server}://{user}:{password}@{ip}/{db_name}')

# open the connection
conn = engine.connect()

# %%
respondente.to_sql('respondente', conn, if_exists='replace', index=False)
empresa.to_sql('empresa', conn, if_exists='replace', index=False)
pais.to_sql('pais', conn, if_exists='replace', index=False)
sistema_operacional.to_sql('sistema_operacional', conn, if_exists='replace', index=False)
linguagem_programacao.to_sql('linguagem_programacao', conn, if_exists='replace', index=False)
resp_usa_linguagem.to_sql('resp_usa_linguagem', conn, if_exists='replace', index=False)
resp_usa_ferramenta.to_sql('resp_usa_ferramenta', conn, if_exists='replace', index=False)
ferramenta_comunic.to_sql('ferramenta_comunic', conn, if_exists='replace', index=False)
